# %%
# print(zero_ex_it)
# Out:
# 0x1e7e936b0112a5447fc9999a175f668f6e3684f344fcf013f5eac034338acb95

# %%
# \# print(test_req[x])
# print(test_req)
# test_req.info()
# print(zero_ex_it)
# test_req = json.dumps(test_req)

# %%
import requests
import json
import pandas as pd
def pull_order_hist_by_hash(hash):
    fixed_into_pd = pd.DataFrame(((requests.get(f'https://limit-orders.1inch.io/v2.0/1/limit-order/events/{"0x" + hash.lower()}').json())[list((requests.get(f'https://limit-orders.1inch.io/v2.0/1/limit-order/events/{"0x" + hash.lower()}').json()).keys())[0]]), columns=['id', 'network', 'logId', 'version', 'action', 'orderHash', 'taker', 'remainingMakerAmount', 'transactionHash', 'blockNumber', 'createDateTime'])
    fixed_into_pd.head()
    return fixed_into_pd
pull_order_hist_by_hash(hash = '1E7E936B0112A5447FC9999A175F668F6E3684F344FCF013F5EAC034338ACB95')
# Out:
#          id  network         logId  version action  \
# 0  14760396        1  log_e72dc908        2   fill
# 1  14760404        1  log_1c2fcc02        2   fill
# 2  14760420        1  log_fd00a1e7        2   fill
# 3  14760520        1  log_49574226        2   fill
# 4  14768119        1  log_950708df        2   fill
#
#                                            orderHash  \
# 0  0x1e7e936b0112a5447fc9999a175f668f6e3684f344fc...
# 1  0x1e7e936b0112a5447fc9999a175f668f6e3684f344fc...
# 2  0x1e7e936b0112a5447fc9999a175f668f6e3684f344fc...
# 3  0x1e7e936b0112a5447fc9999a175f668f6e3684f344fc...
# 4  0x1e7e936b0112a5447fc9999a175f668f6e3684f344fc...
#
#                                         taker  remainingMakerAmount  \
# 0  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8  93210781650543027035
# 1  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8  43188467247487406487
# 2  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8   6142818430381748868
# 3  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8    150735090370649583
# 4  0xf2f400c138f9fb900576263af0bc7fcde2b1b8a8     29100228148202054
#
#                                      transactionHash  blockNumber  \
# 0  0xfcabcd0c9beac0a45b6dad7fcee734f346a9aa799241...     15157679
# 1  0x0a6cef3922636cebb6996653e611ce835b13f7b8c055...     15157680
# 2  0x06d356d248e3d5732f367d3ff55b26256f63b82ff1d1...     15157681
# 3  0x2dcbcd63b645a166083bc6b6644b123fa374b035b3f8...     15157688
# 4  0xf04dc23105c537c61b27fceba5aeae3248f1ffd2a36a...     15158758
#
#              createDateTime
# 0  2022-07-17T03:08:09.179Z
# 1  2022-07-17T03:08:18.192Z
# 2  2022-07-17T03:08:39.194Z
# 3  2022-07-17T03:10:18.247Z
# 4  2022-07-17T07:12:48.930Z

# %%
chainID_dict = { "Ethereum": 1, "Binance Smart Chain": 56, "Polygon": 137, "Optimism": 10, "Arbitrum": 42161, "Gnosis Chain": 100, "Avalanche": 43114, "Fantom": 250 }
chainId_choice = "Ethereum"
# chainId_choice_st = st.selectbox("Select Chain ID", list(chainID_dict.keys()))
chainId = chainID_dict[chainId_choice] 
page = 1 #  page -Pagination step, default: 1 (page = offset / limit) 
sort_by_dict = {'1': 'createDateTime', '2': 'takerRate', '3': 'makerRate', '4': 'makerAmount', '5': 'takerAmount'}
sort_by_choice = '1'
sort_by_choice_st = st.selectbox("Sort by", list(sort_by_dict.keys()))
sortBy = sort_by_dict[sort_by_choice]
limit = 100 #  limit -Number of limit orders to receive (default: 100, max: 500)
# limit_st = st.number_input("Limit", value=100, min_value=1, max_value=500)
status_dict = {'_1_': "%5B1%5D&", '_12_': "%5B1%2C2%5D&", '_123_': "%5B1%2C2%2C3%5D&", '_2_':"%5B2%5D&",'_23_':"%5B2%2C3%5D&",'_3_':"%5B3%5D&"}
status_choice = '_123_' #  statuses [1,2,3] 1 - valid limit orders, 2 - temporary invalid limit orders, 3 - invalid limit orders
# status_choice_st = st.selectbox("Status", list(status_dict.keys()))
status = status_dict[status_choice]
takerAsset = '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48'
makerAsset ='0xdac17f958d2ee523a2206206994597c13d831ec7'
ping_limit_orders = requests.get(f'https://limit-orders.1inch.io/v2.0/{chainId}/limit-order/all?page={page}&limit={limit}&statuses={status}sortBy={sortBy}&takerAsset={takerAsset}&makerAsset={makerAsset}').json()
ping_limit_orders = pd.DataFrame(ping_limit_orders)
ping_limit_orders.head()
# Out:
#                                            signature  \
# 0  0x2ce8b6748877d41917f3ea2d0529fcb7601c66b5a41c...
# 1  0x091704fd32cb8bac5e3c4c14269360b4982f18ff7032...
# 2  0x9f46b8506171009b75d097c57f3524aebe6ca540894c...
# 3  0x2105b3f352c44efdbcd75e501fa31d0b79f36ca6c1d6...
# 4  0x2830e6a5f4764d1f4306efafa14a2626a7581ec44e30...
#
#                                            orderHash  \
# 0  0x7adb6d175aa29c5cc29bcdeee080d0784185cad9418b...
# 1  0x9a952577ac98bdfd90bf0e30ff05c5cc0bc61447298a...
# 2  0x03a7e7ac41455f1e1cb1ed36c1e588a4fda198c58927...
# 3  0x081522a9d780d06960f02ee01b52d4dddd5cdda5bc71...
# 4  0xea64357db9d70a7fcc271876e63116c4b663b93595b8...
#
#              createDateTime remainingMakerAmount makerBalance  \
# 0  2022-07-17T19:07:04.404Z          25008500000  17467180300
# 1  2022-07-17T07:38:02.775Z          25008500000  25008500000
# 2  2022-07-17T04:30:17.995Z          25008500000  25008500000
# 3  2022-07-15T09:17:59.529Z          10000000000  42465630361
# 4  2022-07-15T09:17:05.939Z          10000000000  42465630361
#
#                                       makerAllowance  \
# 0  1157920892373161954235709850086879078532699846...
# 1  1157920892373161954235709850086879078532699846...
# 2  1157920892373161954235709850086879078532699846...
# 3  1157920892373161954235709850086879078532699846...
# 4  1157920892373161954235709850086879078532699846...
#
#                                                 data             makerRate  \
# 0  {'makerAsset': '0xdac17f958d2ee523a22062069945...  1.000073499970010196
# 1  {'makerAsset': '0xdac17f958d2ee523a22062069945...  1.000000000000000000
# 2  {'makerAsset': '0xdac17f958d2ee523a22062069945...  1.000548199972009516
# 3  {'makerAsset': '0xdac17f958d2ee523a22062069945...  0.999500000000000000
# 4  {'makerAsset': '0xdac17f958d2ee523a22062069945...  0.999750800000000000
#
#               takerRate  isMakerContract
# 0  0.999926505431838359            False
# 1  1.000000000000000000            False
# 2  0.999452100386543244            False
# 3  1.000500250125062531            False
# 4  1.000249262116119336            False

# %%
import requests
import json
import pandas as pd
all = requests.get('https://limit-orders.1inch.io/v2.0/1/limit-order/all?page=1&limit=10&statuses=%5B1%2C2%2C3%5D').json()
# all = all['data']
all = pd.DataFrame(all)
all = all['data']
all.head()
# Out:
# 0    {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...
# 1    {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...
# 2    {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...
# 3    {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...
# 4    {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...
# Name: data, dtype: object

# %%
# all = all['data']
# all.head()
import requests
import json
import pandas as pd
all = requests.get('https://limit-orders.1inch.io/v2.0/1/limit-order/all?page=1&limit=10&statuses=%5B1%2C2%2C3%5D').json()
# all = all['data']
all = pd.DataFrame(all)

# all = all['data']
all['makerAsset'] = all['data'][0]['makerAsset']
all['takerAsset'] = all['data'][0]['takerAsset']

# d = {[all[0]['makerAsset']]
# ,[all[0]['takerAsset']]}
# simple_df = pd.DataFrame(data=d,columns=['makerAsset', 'takerAsset'])
# simple_df = simple_df.append(
# )
# # all[0]['makerAsset']
# # all[0]['takerAsset']
# # for row, data in all.i
all.head()
# terrows:
#     print(data)
# Out:
#                                            signature  \
# 0  0x3103ca9e44dc0d71acdc159c209bcafaa7848ca7e348...
# 1  0x01c59904ba624b0661753d9c1a08ef5e2629db9a5945...
# 2  0xa5dc81078dea7b67eaa76e9cde3d9f7872e40014e27e...
# 3  0x9c840ac4fe257b10a542b6ec3f8523e6691b1b44eefd...
# 4  0xd6610a6561c527a782089462133ca8c92b0d106b4411...
#
#                                            orderHash  \
# 0  0xa38cfb28ac4c752e8daa21120064b318013f5de7e303...
# 1  0x69dd689671f984f81746c76acda2c7b2d5f33b9b05d9...
# 2  0x01292181db588007dbe2e043869242ed39eaad216a25...
# 3  0x305c7b9d8b5961df2b4a3e2407f608b8f4d49747e2ad...
# 4  0x1fc537dd1a889f2190ae9ba54f0ce62aed4ae08abf7b...
#
#              createDateTime remainingMakerAmount makerBalance  \
# 0  2022-07-18T11:41:52.975Z          20000000000            0
# 1  2022-07-18T11:41:52.874Z          20000000000            0
# 2  2022-07-18T11:41:52.724Z          20000000000            0
# 3  2022-07-18T11:41:52.428Z          20000000000            0
# 4  2022-07-18T11:41:51.824Z          20000000000            0
#
#                                       makerAllowance  \
# 0  1157920892373161954235709850086879078532699846...
# 1  1157920892373161954235709850086879078532699846...
# 2  1157920892373161954235709850086879078532699846...
# 3  1157920892373161954235709850086879078532699846...
# 4  1157920892373161954235709850086879078532699846...
#
#                                                 data  \
# 0  {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...
# 1  {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...
# 2  {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...
# 3  {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...
# 4  {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...
#
#                            makerRate             takerRate  isMakerContract  \
# 0             971.032267288250000000  0.001029831895074554            False
# 1   7301768985380.116959064300000000           1.36953E-13            False
# 2     21783782711.421098517850000000         4.5905709E-11            False
# 3   2376688557322.414778137450000000           4.20753E-13            False
# 4  24005864980732.177263969150000000            4.1656E-14            False
#
#                                    makerAsset  \
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#                                    takerAsset
# 0  0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b
# 1  0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b
# 2  0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b
# 3  0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b
# 4  0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b

# %%
tokens_list = requests.get(f"https://api.1inch.io/v4.0/1/tokens")
tokens_list = json.loads(tokens_list.text)
tokens_list = [tokens_list["tokens"][x] for x in tokens_list["tokens"]]
# symbol_list = [elem["symbol"] for elem in tokens_list]
# print("Tokens List")
# print("Great!")
tokens_list = pd.DataFrame(tokens_list)
# print(tokens_list)
'''find the symbol for each maker asset by looking in the tokens list and matching the symbol with the maker asset'''
all['makerAsset_symbol'] = all['makerAsset'].apply(lambda x: tokens_list[tokens_list['address'] == x]['symbol'].values[0])
all['takerAsset_symbol'] = all['takerAsset'].apply(lambda x: tokens_list[tokens_list['address'] == x]['symbol'].values[0])
all['makerAsset_decimals'] = all['makerAsset'].apply(lambda x: tokens_list[tokens_list['address'] == x]['decimals'].values[0])
all['takerAsset_decimals'] = all['takerAsset'].apply(lambda x: tokens_list[tokens_list['address'] == x]['decimals'].values[0])
all.head()
     





# all['maker_symbol']
# # tokenIN = st.selectbox("tokenIN", tokens_list['symbol'], index=103)
# address_of_said_tokenIN = (tokens_list.loc['makerAsset'])
# print(address_of_said_tokenIN)
# address_of_said_tokenIN = pd.DataFrame(address_of_said_tokenIN)
# print(address_of_said_tokenIN)# print(address_of_said_tokenIN)

# all = all.merge(address_of_said_tokenIN, left_on='makerAsset', right_index=True)
# all['maker_symbol'] = address_of_said_tokenIN
# # all.head()
# decimal_of_said_tokenIN = tokens_list.set_index("address").loc[all['makerAsset']]["decimals"]
# # all = all.merge(decimal_of_said_tokenIN, left_on='makerAsset', right_index=True)

# # print(decimal_of_said_tokenIN)

# # # tokenOUT = st.selectbox("tokenOUT", tokens_list['symbol'], index=146)
# address_of_said_tokenOUT = tokens_list.set_index("address").loc[all['takerAsset']]["symbol"]
# # all = all.merge(address_of_said_tokenOUT, left_on='takerAsset', right_index=True)

# # print(address_of_said_tokenOUT)

# decimal_of_said_tokenOUT = tokens_list.set_index("address").loc[all['takerAsset']]["decimals"]
# # all = all.merge(decimal_of_said_tokenOUT, left_on='takerAsset', right_index=True)
# # all.head()

# # print(decimal_of_said_tokenOUT)
# Out:
#                                            signature  \
# 0  0x3103ca9e44dc0d71acdc159c209bcafaa7848ca7e348...
# 0  0x3103ca9e44dc0d71acdc159c209bcafaa7848ca7e348...
# 0  0x3103ca9e44dc0d71acdc159c209bcafaa7848ca7e348...
# 0  0x3103ca9e44dc0d71acdc159c209bcafaa7848ca7e348...
# 0  0x3103ca9e44dc0d71acdc159c209bcafaa7848ca7e348...
#
#                                            orderHash  \
# 0  0xa38cfb28ac4c752e8daa21120064b318013f5de7e303...
# 0  0xa38cfb28ac4c752e8daa21120064b318013f5de7e303...
# 0  0xa38cfb28ac4c752e8daa21120064b318013f5de7e303...
# 0  0xa38cfb28ac4c752e8daa21120064b318013f5de7e303...
# 0  0xa38cfb28ac4c752e8daa21120064b318013f5de7e303...
#
#              createDateTime remainingMakerAmount makerBalance  \
# 0  2022-07-18T11:41:52.975Z          20000000000            0
# 0  2022-07-18T11:41:52.975Z          20000000000            0
# 0  2022-07-18T11:41:52.975Z          20000000000            0
# 0  2022-07-18T11:41:52.975Z          20000000000            0
# 0  2022-07-18T11:41:52.975Z          20000000000            0
#
#                                       makerAllowance  \
# 0  1157920892373161954235709850086879078532699846...
# 0  1157920892373161954235709850086879078532699846...
# 0  1157920892373161954235709850086879078532699846...
# 0  1157920892373161954235709850086879078532699846...
# 0  1157920892373161954235709850086879078532699846...
#
#                                                 data               makerRate  \
# 0  {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...  971.032267288250000000
# 0  {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...  971.032267288250000000
# 0  {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...  971.032267288250000000
# 0  {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...  971.032267288250000000
# 0  {'makerAsset': '0xa0b86991c6218b36c1d19d4a2e9e...  971.032267288250000000
#
#               takerRate  isMakerContract  \
# 0  0.001029831895074554            False
# 0  0.001029831895074554            False
# 0  0.001029831895074554            False
# 0  0.001029831895074554            False
# 0  0.001029831895074554            False
#
#                                    makerAsset  \
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#                                    takerAsset symbol_x symbol_y  \
# 0  0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b     USDC     USDC
# 0  0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b     USDC     USDC
# 0  0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b     USDC     USDC
# 0  0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b     USDC     USDC
# 0  0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b     USDC     USDC
#
#                                  maker_symbol makerAsset_symbol  \
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48              USDC
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48              USDC
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48              USDC
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48              USDC
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48              USDC
#
#   takerAsset_symbol  makerAsset_decimals  takerAsset_decimals
# 0               CRO                    6                    8
# 0               CRO                    6                    8
# 0               CRO                    6                    8
# 0               CRO                    6                    8
# 0               CRO                    6                    8

# %%
tokens_list = requests.get(f"https://api.1inch.io/v4.0/1/tokens")
tokens_list = json.loads(tokens_list.text)
tokens_list = tokens_list["tokens"]
tokens_list = pd.DataFrame(tokens_list)
tokens_list = tokens_list.T
tokens_list = tokens_list.reset_index()
tokens_list = tokens_list.drop(columns=['index','logoURI', 'tags', 'eip2612', 'isFoT', 'synth', 'displayedSymbol'])

(tokens_list).head()
ls = ['0xf01a670973edc81865ebb9f68b10c47c31afc133', '0xae7ab96520de3a18e5e111b5eaab095312d7fe84', '0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0', '0xf01a670973edc81865ebb9f68b10c47c31afc133', 340000000000000000, 564397840925300413418]
ls2 = ['0xf01a670973edc81865ebb9f68b10c47c31afc133', '0xae7ab96520de3a18e5e111b5eaab095312d7fe84', '0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0', '0xf01a670973edc81865ebb9f68b10c47c31afc133', 340000000000000000, 564397840925300413418]
from datetime import datetime
now = datetime.now()

ls = pd.DataFrame([ls], columns=['a', 'b', 'c', 'd', 'e', 'f'])
ls2 = pd.DataFrame([ls2], columns=['a', 'b', 'c', 'd', 'e', 'f'])
ls = ls.append(ls2, ignore_index=True)
ls['token1'] = [tokens_list.loc[tokens_list['address'] == b, 'symbol'].values[0] for b in ls['b']]
ls['token2'] = [tokens_list.loc[tokens_list['address'] == b, 'symbol'].values[0] for b in ls['c']]
ls
# Out:
#                                             a  \
# 0  0xf01a670973edc81865ebb9f68b10c47c31afc133
# 1  0xf01a670973edc81865ebb9f68b10c47c31afc133
#
#                                             b  \
# 0  0xae7ab96520de3a18e5e111b5eaab095312d7fe84
# 1  0xae7ab96520de3a18e5e111b5eaab095312d7fe84
#
#                                             c  \
# 0  0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0
# 1  0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0
#
#                                             d                   e  \
# 0  0xf01a670973edc81865ebb9f68b10c47c31afc133  340000000000000000
# 1  0xf01a670973edc81865ebb9f68b10c47c31afc133  340000000000000000
#
#                        f token1 token2
# 0  564397840925300413418  stETH  MATIC
# 1  564397840925300413418  stETH  MATIC

# %%
chainId = 1
page = 1 #  page -Pagination step, default: 1 (page = offset / limit)
limit = 100 #  limit -Number of limit orders to receive (default: 100, max: 500)
status = "%5B1%5D&"
sortBy = 'createDateTime'
url = f'https://limit-orders.1inch.io/v2.0/{chainId}/limit-order/all?page={page}&limit={limit}&statuses={status}sortBy={sortBy}'
ping_limit_orders = requests.get(url).json()
ping_limit_orders = pd.DataFrame(ping_limit_orders)
ping_limit_orders['maker_asset'] = ping_limit_orders['data'][0]['makerAsset']
ping_limit_orders['taker_asset'] = ping_limit_orders['data'][0]['takerAsset']
ping_limit_orders = ping_limit_orders.drop(columns=['data', 'signature','orderHash'])
ping_limit_orders.head()
# Out:
#              createDateTime remainingMakerAmount makerBalance  \
# 0  2022-07-19T12:32:10.864Z          20000000000            0
# 1  2022-07-19T12:32:10.169Z          20000000000            0
# 2  2022-07-19T12:32:04.067Z          20000000000            0
# 3  2022-07-19T12:32:03.648Z          20000000000            0
# 4  2022-07-19T12:32:00.896Z          20000000000            0
#
#                                       makerAllowance  \
# 0  1157920892373161954235709850086879078532699846...
# 1  1157920892373161954235709850086879078532699846...
# 2  1157920892373161954235709850086879078532699846...
# 3  1157920892373161954235709850086879078532699846...
# 4  1157920892373161954235709850086879078532699846...
#
#                            makerRate       takerRate  isMakerContract  \
# 0   1250125012501.250125012500000000     7.99920E-13            False
# 1  42158516020236.087689713300000000      2.3720E-14            False
# 2   6018997354085.603112840450000000     1.66140E-13            False
# 3      1145047822.557181337800000000  8.73325969E-10            False
# 4  60898095123177.476118652550000000      1.6420E-14            False
#
#                                   maker_asset  \
# 0  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#                                   taker_asset
# 0  0x6b175474e89094c44da98b954eedeac495271d0f
# 1  0x6b175474e89094c44da98b954eedeac495271d0f
# 2  0x6b175474e89094c44da98b954eedeac495271d0f
# 3  0x6b175474e89094c44da98b954eedeac495271d0f
# 4  0x6b175474e89094c44da98b954eedeac495271d0f

# %%
# chainId = 1
import math
tokens_list = requests.get(f"https://api.1inch.io/v4.0/{chainId}/tokens")
tokens_list = json.loads(tokens_list.text)
tokens_list = tokens_list["tokens"]
tokens_list = pd.DataFrame(tokens_list)
tokens_list = tokens_list.T
tokens_list = tokens_list.reset_index()
tokens_list = tokens_list.drop(columns=['index','logoURI', 'tags', 'eip2612', 'isFoT', 'synth', 'displayedSymbol'])
# print(tokens_list)



ping_limit_orders['maker_asset_addy'] = ping_limit_orders['maker_asset']
ping_limit_orders['taker_asset_addy'] = ping_limit_orders['taker_asset']
ping_limit_orders['maker_asset_decimalz'] = ping_limit_orders['maker_asset']
ping_limit_orders['taker_asset_decimalz'] = ping_limit_orders['taker_asset']
ping_limit_orders['maker_asset_decimalz'] = [tokens_list.loc[tokens_list['address'] == b, 'decimals'].values[0] for b in ping_limit_orders['maker_asset_decimalz']]
ping_limit_orders['taker_asset_decimalz'] = [tokens_list.loc[tokens_list['address'] == b, 'decimals'].values[0] for b in ping_limit_orders['taker_asset_decimalz']]
ping_limit_orders['maker_asset'] = [tokens_list.loc[tokens_list['address'] == b, 'symbol'].values[0] for b in ping_limit_orders['maker_asset']]
ping_limit_orders['taker_asset'] = [tokens_list.loc[tokens_list['address'] == b, 'symbol'].values[0] for b in ping_limit_orders['taker_asset']]
ping_limit_orders['maker_amount_fixed'] = ping_limit_orders['remainingMakerAmount'] / math.pow(10, ping_limit_orders['maker_asset_decimalz'])
# makerRate	
# takerRate
ping_limit_orders
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\User\new_21\21\1inchparser.ipynb Cell 10 in <cell line: 22>()
#      <a href='vscode-notebook-cell:/c%3A/Users/User/new_21/21/1inchparser.ipynb#ch0000009?line=19'>20</a> ping_limit_orders['maker_asset'] = [tokens_list.loc[tokens_list['address'] == b, 'symbol'].values[0] for b in ping_limit_orders['maker_asset']]
#      <a href='vscode-notebook-cell:/c%3A/Users/User/new_21/21/1inchparser.ipynb#ch0000009?line=20'>21</a> ping_limit_orders['taker_asset'] = [tokens_list.loc[tokens_list['address'] == b, 'symbol'].values[0] for b in ping_limit_orders['taker_asset']]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/new_21/21/1inchparser.ipynb#ch0000009?line=21'>22</a> ping_limit_orders['maker_amount_fixed'] = ping_limit_orders['remainingMakerAmount'] / math.pow(10, ping_limit_orders['maker_asset_decimalz'])
#      <a href='vscode-notebook-cell:/c%3A/Users/User/new_21/21/1inchparser.ipynb#ch0000009?line=22'>23</a> # makerRate
#      <a href='vscode-notebook-cell:/c%3A/Users/User/new_21/21/1inchparser.ipynb#ch0000009?line=23'>24</a> # takerRate
#      <a href='vscode-notebook-cell:/c%3A/Users/User/new_21/21/1inchparser.ipynb#ch0000009?line=24'>25</a> ping_limit_orders
#
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:185, in _coerce_method.<locals>.wrapper(self)
#     183 if len(self) == 1:
#     184     return converter(self.iloc[0])
# --> 185 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>
