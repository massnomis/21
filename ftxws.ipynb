# %%
import pandas as pd
null = None
true = True
false = False
fill_data = {
  "channel": "fills",
  "type": "update",
  "data": {
    "id": 9121995008,
    "market": "GST-PERP",
    "future": "GST-PERP",
    "baseCurrency": null,
    "quoteCurrency": null,
    "type": "order",
    "side": "sell",
    "price": 0.076,
    "size": 1,
    "orderId": 163547025488,
    "time": "2022-07-17T08:03:07.774010+00:00",
    "tradeId": 4520683783,
    "feeRate": 0.0007,
    "fee": 0.0000532,
    "feeCurrency": "USD",
    "liquidity": "taker",
    "clientOrderId": null
  }
}
print(fill_data)
data = fill_data['data']
data = pd.DataFrame(data, index=[0])
print(data['market'])
print(data['future'])
print(data['baseCurrency'])
print(data['quoteCurrency'])
print(data['type'])
print(data['side'])
print(data['price'])
print(data['size'])
print(data['orderId'])
print(data['time'])
print(data['tradeId'])
print(data['feeRate'])
print(data['fee'])
print(data['feeCurrency'])
print(data['liquidity'])
print(data['clientOrderId'])
# Out:
# {'channel': 'fills', 'type': 'update', 'data': {'id': 9121995008, 'market': 'GST-PERP', 'future': 'GST-PERP', 'baseCurrency': None, 'quoteCurrency': None, 'type': 'order', 'side': 'sell', 'price': 0.076, 'size': 1, 'orderId': 163547025488, 'time': '2022-07-17T08:03:07.774010+00:00', 'tradeId': 4520683783, 'feeRate': 0.0007, 'fee': 5.32e-05, 'feeCurrency': 'USD', 'liquidity': 'taker', 'clientOrderId': None}}
# 0    GST-PERP
# Name: market, dtype: object
# 0    GST-PERP
# Name: future, dtype: object
# 0    None
# Name: baseCurrency, dtype: object
# 0    None
# Name: quoteCurrency, dtype: object
# 0    order
# Name: type, dtype: object
# 0    sell
# Name: side, dtype: object
# 0    0.076
# Name: price, dtype: float64
# 0    1
# Name: size, dtype: int64
# 0    163547025488
# Name: orderId, dtype: int64
# 0    2022-07-17T08:03:07.774010+00:00
# Name: time, dtype: object
# 0    4520683783
# Name: tradeId, dtype: int64
# 0    0.0007
# Name: feeRate, dtype: float64
# 0    0.000053
# ...

# %%
data.head()
# Out:
#            id    market    future baseCurrency quoteCurrency   type  side  \
# 0  9121995008  GST-PERP  GST-PERP         None          None  order  sell
#
#    price  size       orderId                              time     tradeId  \
# 0  0.076     1  163547025488  2022-07-17T08:03:07.774010+00:00  4520683783
#
#    feeRate       fee feeCurrency liquidity clientOrderId
# 0   0.0007  0.000053         USD     taker          None

# %%
import ccxt
import pandas as pd
from itertools import accumulate
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from itertools import chain
import numpy as np
import plotly.express as px
from datetime import datetime, timedelta
import math

exchange = ccxt.bitmex({
    'apiKey': 'NOAb2TuyuLgWkYbXOQGH-x9b',
    'secret': '_fAxf57mItdpX-A5KTxXRzJZY3zkeSKdCGlStwa95FAH81Gd',
})
if 'test' in exchange.urls:
    exchange.urls['api'] = exchange.urls['test'] # ←----- switch the base URL to testnet
orders_hist = exchange.fetchOpenOrders()
orders_hist = pd.DataFrame(orders_hist)
print(orders_hist.columns)
orders_hist.head()
# Out:
# Index(['info', 'id', 'clientOrderId', 'timestamp', 'datetime',
#        'lastTradeTimestamp', 'symbol', 'type', 'timeInForce', 'postOnly',
#        'side', 'price', 'stopPrice', 'amount', 'cost', 'average', 'filled',
#        'remaining', 'status', 'fee', 'trades', 'fees'],
#       dtype='object')
# 0    {'orderID': 'fe8ef468-b594-4c75-bd86-14e3945e9...
# Name: info, dtype: object

# %%
orders_hist = exchange.fetchOpenOrders()
orders_hist = pd.DataFrame(orders_hist)
orders_hist = orders_hist[orders_hist.side != 'buy']
orders_hist_id_df = pd.DataFrame(orders_hist['id'])
print(orders_hist_id_df)
# id = orders_hist_id_df
# order_cancel_df = pd.DataFrame()
# cancel_df = pd.DataFrame()

# for index, row in id.iterrows():
    # order_cancel = exchange.cancelOrder(id=row['id'])
    # order_cancel_df = order_cancel_df.append(order_cancel, ignore_index=True).astype(str)
# orders_hist
# orders_hist = orders_hist[orders_hist.side != 'sell']
# Out:
#                                      id
# 1  2cb9b741-1e8d-4c8f-83ea-971307313c02

# %%
    for col_name, data in bid_new.iterrows():
        while i < orders_to_place_a_side:

            mm_bid_price = (data['mm_bid_price']) - (precision_price * np.random.randint(3) *i)
            mm_bid_size = (data['mm_bid_size']) 
            order_init_bid = exchange.createLimitBuyOrder(symbol=symbol,price=mm_bid_price,amount=mm_bid_size)
            order_df_bid = order_df_bid.append(order_init_bid, ignore_index=True)
            i += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User\new_21\21\ftxws.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/new_21/21/ftxws.ipynb#ch0000005?line=0'>1</a> for col_name, data in bid_new.iterrows():
#       <a href='vscode-notebook-cell:/c%3A/Users/User/new_21/21/ftxws.ipynb#ch0000005?line=1'>2</a>     while i < orders_to_place_a_side:
#       <a href='vscode-notebook-cell:/c%3A/Users/User/new_21/21/ftxws.ipynb#ch0000005?line=3'>4</a>         mm_bid_price = (data['mm_bid_price']) - (precision_price * np.random.randint(3) *i)
#
# NameError: name 'bid_new' is not defined

# %%
null = None
true = True
false = False
df_one = [
  {
    "info": {
      "orderID": "6d23b697-ad19-4ae4-b3af-e4d79b1fd24a",
      "clOrdID": "",
      "clOrdLinkID": "",
      "account": "403419",
      "symbol": "LINK_USDT",
      "side": "Buy",
      "simpleOrderQty": null,
      "orderQty": "10000000",
      "price": "6.525",
      "displayQty": null,
      "stopPx": null,
      "pegOffsetValue": null,
      "pegPriceType": "",
      "currency": "USDT",
      "settlCurrency": "",
      "ordType": "Limit",
      "timeInForce": "GoodTillCancel",
      "execInst": "",
      "contingencyType": "",
      "exDestination": "XBME",
      "ordStatus": "New",
      "triggered": "",
      "workingIndicator": true,
      "ordRejReason": "",
      "simpleLeavesQty": null,
      "leavesQty": "10000000",
      "simpleCumQty": null,
      "cumQty": "0",
      "avgPx": null,
      "multiLegReportingType": "SingleSecurity",
      "text": "Submitted via API.",
      "transactTime": "2022-07-17T12:03:40.758Z",
      "timestamp": "2022-07-17T12:03:40.758Z"
    },
    "id": "6d23b697-ad19-4ae4-b3af-e4d79b1fd24a",
    "clientOrderId": null,
    "timestamp": 1658059420758,
    "datetime": "2022-07-17T12:03:40.758Z",
    "lastTradeTimestamp": 1658059420758,
    "symbol": "LINK_USDT",
    "type": "limit",
    "timeInForce": "GTC",
    "postOnly": null,
    "side": "buy",
    "price": 6.525,
    "stopPrice": null,
    "amount": 10000000,
    "cost": 0,
    "average": null,
    "filled": 0,
    "remaining": 10000000,
    "status": "open",
    "fee": null,
    "trades": [],
    "fees": []
  },
  {
    "info": {
      "orderID": "4c96664b-b054-4e1e-866b-c379770156bb",
      "clOrdID": "",
      "clOrdLinkID": "",
      "account": "403419",
      "symbol": "LINK_USDT",
      "side": "Buy",
      "simpleOrderQty": null,
      "orderQty": "10000000",
      "price": "6.523",
      "displayQty": null,
      "stopPx": null,
      "pegOffsetValue": null,
      "pegPriceType": "",
      "currency": "USDT",
      "settlCurrency": "",
      "ordType": "Limit",
      "timeInForce": "GoodTillCancel",
      "execInst": "",
      "contingencyType": "",
      "exDestination": "XBME",
      "ordStatus": "New",
      "triggered": "",
      "workingIndicator": true,
      "ordRejReason": "",
      "simpleLeavesQty": null,
      "leavesQty": "10000000",
      "simpleCumQty": null,
      "cumQty": "0",
      "avgPx": null,
      "multiLegReportingType": "SingleSecurity",
      "text": "Submitted via API.",
      "transactTime": "2022-07-17T12:03:42.760Z",
      "timestamp": "2022-07-17T12:03:42.760Z"
    },
    "id": "4c96664b-b054-4e1e-866b-c379770156bb",
    "clientOrderId": null,
    "timestamp": 1658059422760,
    "datetime": "2022-07-17T12:03:42.760Z",
    "lastTradeTimestamp": 1658059422760,
    "symbol": "LINK_USDT",
    "type": "limit",
    "timeInForce": "GTC",
    "postOnly": null,
    "side": "buy",
    "price": 6.523,
    "stopPrice": null,
    "amount": 10000000,
    "cost": 0,
    "average": null,
    "filled": 0,
    "remaining": 10000000,
    "status": "open",
    "fee": null,
    "trades": [],
    "fees": []
  },
  {
    "info": {
      "orderID": "1aff69d7-3662-4861-ab22-2dbdba95f325",
      "clOrdID": "",
      "clOrdLinkID": "",
      "account": "403419",
      "symbol": "LINK_USDT",
      "side": "Buy",
      "simpleOrderQty": null,
      "orderQty": "10000000",
      "price": "6.525",
      "displayQty": null,
      "stopPx": null,
      "pegOffsetValue": null,
      "pegPriceType": "",
      "currency": "USDT",
      "settlCurrency": "",
      "ordType": "Limit",
      "timeInForce": "GoodTillCancel",
      "execInst": "",
      "contingencyType": "",
      "exDestination": "XBME",
      "ordStatus": "New",
      "triggered": "",
      "workingIndicator": true,
      "ordRejReason": "",
      "simpleLeavesQty": null,
      "leavesQty": "10000000",
      "simpleCumQty": null,
      "cumQty": "0",
      "avgPx": null,
      "multiLegReportingType": "SingleSecurity",
      "text": "Submitted via API.",
      "transactTime": "2022-07-17T12:03:44.785Z",
      "timestamp": "2022-07-17T12:03:44.785Z"
    },
    "id": "1aff69d7-3662-4861-ab22-2dbdba95f325",
    "clientOrderId": null,
    "timestamp": 1658059424785,
    "datetime": "2022-07-17T12:03:44.785Z",
    "lastTradeTimestamp": 1658059424785,
    "symbol": "LINK_USDT",
    "type": "limit",
    "timeInForce": "GTC",
    "postOnly": null,
    "side": "buy",
    "price": 6.525,
    "stopPrice": null,
    "amount": 10000000,
    "cost": 0,
    "average": null,
    "filled": 0,
    "remaining": 10000000,
    "status": "open",
    "fee": null,
    "trades": [],
    "fees": []
  },
  {
    "info": {
      "orderID": "9a1e7637-ef96-429d-8d9d-8875cc185e71",
      "clOrdID": "",
      "clOrdLinkID": "",
      "account": "403419",
      "symbol": "LINK_USDT",
      "side": "Buy",
      "simpleOrderQty": null,
      "orderQty": "10000000",
      "price": "6.522",
      "displayQty": null,
      "stopPx": null,
      "pegOffsetValue": null,
      "pegPriceType": "",
      "currency": "USDT",
      "settlCurrency": "",
      "ordType": "Limit",
      "timeInForce": "GoodTillCancel",
      "execInst": "",
      "contingencyType": "",
      "exDestination": "XBME",
      "ordStatus": "New",
      "triggered": "",
      "workingIndicator": true,
      "ordRejReason": "",
      "simpleLeavesQty": null,
      "leavesQty": "10000000",
      "simpleCumQty": null,
      "cumQty": "0",
      "avgPx": null,
      "multiLegReportingType": "SingleSecurity",
      "text": "Submitted via API.",
      "transactTime": "2022-07-17T12:03:46.785Z",
      "timestamp": "2022-07-17T12:03:46.785Z"
    },
    "id": "9a1e7637-ef96-429d-8d9d-8875cc185e71",
    "clientOrderId": null,
    "timestamp": 1658059426785,
    "datetime": "2022-07-17T12:03:46.785Z",
    "lastTradeTimestamp": 1658059426785,
    "symbol": "LINK_USDT",
    "type": "limit",
    "timeInForce": "GTC",
    "postOnly": null,
    "side": "buy",
    "price": 6
      "contingencyType": "",
      "exDestination": "XBME",
      "ordStatus": "New",
      "triggered": "",
      "workingIndicator": true,
      "ordRejReason": "",
      "simpleLeavesQty": null,
      "leavesQty": "10000000",
      "simpleCumQty": null,
      "cumQty": "0",
      "avgPx": null,
      "multiLegReportingType": "SingleSecurity",
      "text": "Submitted via API.",
      "transactTime": "2022-07-17T12:04:02.887Z",
      "timestamp": "2022-07-17T12:04:02.887Z"
    },
    "id": "5fd0ab92-31e6-4a4d-b7cf-2532a9fb13d5",
    "clientOrderId": null,
    "timestamp": 1658059442887,
    "datetime": "2022-07-17T12:04:02.887Z",
    "lastTradeTimestamp": 1658059442887,
    "symbol": "LINK_USDT",
    "type": "limit",
    "timeInForce": "GTC",
    "postOnly": null,
    "side": "buy",
    "price": 6.503,
    "stopPrice": null,
    "amount": 10000000,
    "cost": 0,
    "average": null,
    "filled": 0,
    "remaining": 10000000,
    "status": "open",
    "fee": null,
    "trades": [],
    "fees": []
  }
]
df_one = pd.DataFrame(df_one)
df_one = df_one[df_one.side != 'buy']

data = (exchange.fetchOrderBook('LINK_USDT')) 
df_two = data["bids"]
df_two = pd.DataFrame(df_two)
df_two = df_two.rename(columns={0: "price_bid", 1: "size_bid"})
# print(df_two)
# df_one = pd.DataFrame(df_one)
# df_one.head()

# %%
symbol = 'LINK_USDT'
side = 'buy'
price = 6.502
amount = 10000000
order_type = 'limit'
id = '2cb9b741-1e8d-4c8f-83ea-971307313c02'
order_init_bid = exchange.editOrder(id=id,symbol=symbol,type=type,side=side,price=price,amount=amount)
print(order_init_bid)
# Out:
# {'info': {'orderID': '2cb9b741-1e8d-4c8f-83ea-971307313c02', 'clOrdID': '', 'clOrdLinkID': '', 'account': '403419', 'symbol': 'LINK_USDT', 'side': 'Sell', 'simpleOrderQty': None, 'orderQty': '10000000', 'price': '6.502', 'displayQty': None, 'stopPx': None, 'pegOffsetValue': None, 'pegPriceType': '', 'currency': 'USDT', 'settlCurrency': '', 'ordType': 'Limit', 'timeInForce': 'GoodTillCancel', 'execInst': '', 'contingencyType': '', 'exDestination': 'XBME', 'ordStatus': 'New', 'triggered': '', 'workingIndicator': True, 'ordRejReason': '', 'simpleLeavesQty': None, 'leavesQty': '10000000', 'simpleCumQty': None, 'cumQty': '0', 'avgPx': None, 'multiLegReportingType': 'SingleSecurity', 'text': 'Amended orderQty price: Amended via API.\nSubmission from testnet.bitmex.com', 'transactTime': '2022-07-17T13:32:38.143Z', 'timestamp': '2022-07-17T13:32:38.143Z'}, 'id': '2cb9b741-1e8d-4c8f-83ea-971307313c02', 'clientOrderId': None, 'timestamp': 1658064758143, 'datetime': '2022-07-17T13:32:38.143Z', 
# ...

# %%
# for i in range(0, len(df_one.index)):
orders_to_place_a_side = 10
i = 0
symbol = 'LINK_USDT'
for col_name, data in df_one.iterrows():
    for col_name, data in df_two.iterrows():
        while i < orders_to_place_a_side:
    
            id = (df_one['id']) 
            print(df_two['price_bid'])
            order_init_bid = exchange.editOrder(id=id,symbol=symbol,price=mm_bid_price,amount=mm_bid_size)
            order_df_bid = order_df_bid.append(order_init_bid, ignore_index=True)
            i += 1
